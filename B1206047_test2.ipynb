# %%
y = 4

# %%
a = 100
b = 2*y+1

z= a/b

print("Ans. is =", z )
# Out:
# Ans. is = 33.333333333333336

# %%
print(type(a))
print(type(b))
print(type(z))

print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
